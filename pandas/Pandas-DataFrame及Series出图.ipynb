# %%
import pandas as pd

# %%
ser = pd.Series([1, 2, 3, 3])
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# dtype: int64

# %%
plot = ser.plot(kind='hist', title="My plot")

# %%
df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],
                  'width': [0.7, 0.2, 0.15, 0.2, 1.1]},
                  index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
df
# Out:
#          length  width
# pig         1.5   0.70
# rabbit      0.5   0.20
# duck        1.2   0.15
# chicken     0.9   0.20
# horse       3.0   1.10

# %%
plot = df.plot(title="DataFrame Plot")

# %%
lst = [-1, -2, -3, 1, 2, 3]
ser = pd.Series([1, 2, 2, 4, 6, 6], index=lst)
plot = ser.groupby(lambda x: x > 0).plot(title="SeriesGroupBy Plot") # 分组后,索引值>0即[1,2,3]和[-1,-2,-3]各位一组,所以有两段

# %%
plot = ser.plot()

# %%
df = pd.DataFrame({"col1" : [1, 2, 3, 4],
                  "col2" : ["A", "B", "A", "B"]})
df
# Out:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    A
# 3     4    B

# %%
# col2分组,A一组,B一组,展示的是A组和B组中col1的值
plot = df.groupby("col2").plot(kind="bar", title="DataFrameGroupBy Plot")
