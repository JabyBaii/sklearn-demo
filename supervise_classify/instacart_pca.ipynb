# %% [markdown]
# # PCA降维

# %%
# 1、获取数据
# 2、合并表
# 3、找到user_id和aisle之间的关系
# 4、PCA降维

# %%
import pandas as pd

# %%
# 1、获取数据
order_products = pd.read_csv("../data_big/instacart/order_products__prior.csv")
products = pd.read_csv("../data_big/instacart/products.csv")
orders = pd.read_csv("../data_big/instacart/orders.csv")
aisles = pd.read_csv("../data_big/instacart/aisles.csv")

# %%
# 2、合并表
# order_products__prior.csv：订单与商品信息

# 字段：order_id, product_id, add_to_cart_order, reordered
# products.csv：商品信息
# 字段：product_id, product_name, aisle_id, department_id
# orders.csv：用户的订单信息
# 字段：order_id,user_id,eval_set,order_number,….
# aisles.csv：商品所属具体物品类别
# 字段： aisle_id, aisle

# 合并aisles和products aisle和product_id
tab1 = pd.merge(aisles, products, on=["aisle_id", "aisle_id"])

# %%
tab2 = pd.merge(tab1, order_products, on=["product_id", "product_id"])

# %%
tab3 = pd.merge(tab2, orders, on=["order_id", "order_id"])

# %%
tab3.head()
# Out:
#    aisle_id                  aisle  product_id         product_name  \
# 0         1  prepared soups salads         209  Italian Pasta Salad
# 1         1  prepared soups salads         209  Italian Pasta Salad
# 2         1  prepared soups salads         209  Italian Pasta Salad
# 3         1  prepared soups salads         209  Italian Pasta Salad
# 4         1  prepared soups salads         209  Italian Pasta Salad
#
#    department_id  order_id  add_to_cart_order  reordered  user_id eval_set  \
# 0             20     94246                  5          0   114082    prior
# 1             20    192465                  2          1   119977    prior
# 2             20    195206                 18          1     1519    prior
# 3             20    227717                  1          1   161125    prior
# 4             20    260072                 13          0    12012    prior
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order
# ...

# %%
# 3、找到user_id和aisle之间的关系
table = pd.crosstab(tab3["user_id"], tab3["aisle"])

# %%
tab3.shape
# Out:
# (32434489, 14)

# %%
table.head()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            3                 0
# 3                             0            0                 0
# 4                             0            0                 0
# 5                             0            2                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# 3                          0                  0                0
# 4                          0                  0                0
# 5                          0                  0                0
#
# aisle    baking ingredients  baking supplies decor  beauty  beers coolers  \
# user_id
# 1                         0                      0       0              0
# ...

# %%
data = table[:10000]

# %%
# 4、PCA降维
from sklearn.decomposition import PCA

# %%
# 1）实例化一个转换器类
transfer = PCA(n_components=0.95)

# 2）调用fit_transform
data_new = transfer.fit_transform(data)

# %%
data_new.shape
# Out:
# (10000, 42)
